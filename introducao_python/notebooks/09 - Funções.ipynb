# %% [markdown]
# # Funções
#
# - Trechos de programa que recebem um determinado nome e podem ser chamados várias vezes durante a execução
# - Principais vantagens: reutilização de código, modularidade e facilidade de manutenção do sistema

# %% [markdown]
# ## Função sem parâmetro e sem retorno

# %%
def mensagem():
  print('Texto da função')

# %%
mensagem()
# Out:
# Texto da função

# %% [markdown]
# ## Função com passagem de parâmetro

# %%
def mensagem(texto):
  print(texto)

# %%
mensagem('texto 1')
mensagem('texto 2')
mensagem('texto 3')
# Out:
# texto 1
# texto 2
# texto 3

# %%
def soma(a, b):
  print(a + b)

# %%
soma(2, 3)
# Out:
# 5

# %%
soma(3, 3)
soma(1, 2)
# Out:
# 6
# 3

# %% [markdown]
# ## Função com passagem de parâmetros e retorno

# %%
def soma(a, b):
  return a + b

# %%
soma(3, 2)
# Out:
# 5

# %%
r = soma(3, 2)
print(r)
# Out:
# 5

# %%
#
'''
dsfijsahdf
adsfkhsdçflasd
'''

# O exemplo a seguir mostra como usar um valor de parâmetro padrão
def calcula_energia_potencial_gravitacional(m, h, g = 10):
  '''
  Calcula a energia potencial gravitacional
  Argumentos:
  m: massa, entrada como uma variável float
  h: altura, entrada como uma variável float

  Argumento opcional:
  g: aceleração gravitacional, com valor default de 10
  '''
  e = g * m * h
  return e

# %%
calcula_energia_potencial_gravitacional(30, 12)
# Out:
# 3600

# %%
calcula_energia_potencial_gravitacional(30, 12, 9.8)
# Out:
# 3528.0

# %%
# Exibe a descrição da função
help(calcula_energia_potencial_gravitacional)
# Out:
# Help on function calcula_energia_potencial_gravitacional in module __main__:
#
# calcula_energia_potencial_gravitacional(m, h, g=10)
#     Calcula a energia potencial gravitacional
#     Argumentos:
#     m: massa, entrada como uma variável float
#     h: altura, entrada como uma variável float
#
#     Argumento opcional:
#     g: aceleração gravitacional, com valor default de 10

# %% [markdown]
# Funções em Python podem retornar mais de um valor

# %%
# Exemplo de função que retorna mais de um valor.
def quociente_resto(x, y):
    # Calcula o quociente da divisão de x por y usando o operador "//".
    quociente = x // y
    # Calcula o resto da divisão de x por y usando o operador "%".
    resto = x % y
    # Retorna uma tupla contendo os valores calculados (quociente, resto).
    return (quociente, resto)

quociente, resto = quociente_resto(9, 4)
# Chama a função "quociente_resto" com argumentos 9 e 4 e imprime o resultado.
print(f'Quociente: {quociente} e resto: {resto}')
# Out:
# Quociente: 2 e resto: 1

# %% [markdown]
# # Escopo de variáveis
#
# Python possui dois principais tipos de escopo de variáveis: escopo local e escopo global.

# %%
# Variável global
global_var = 10

# %%
# Função que define uma variável local
def funcao_exemplo():
    # Variável local dentro da função
    local_var = 5
    print("Variável local dentro da função:", local_var)

# %%
# Chamada da função
funcao_exemplo()
# Out:
# Variável local dentro da função: 5

# %%
# Tentativa de acessar a variável local fora da função (gera um erro)
#print("Tentativa de acessar variável local fora da função:", local_var)

# Acesso à variável global fora da função
#print("Variável global fora da função:", global_var)
# Out:
# Variável global fora da função: 10
