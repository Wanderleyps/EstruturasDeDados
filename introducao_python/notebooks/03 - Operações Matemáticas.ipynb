# %% [markdown]
# # Operações matemáticas

# %% [markdown]
# ## Operações matemáticas

# %%
a = 5
b = 3
print(a, b)
# Out:
# 5 3

# %%
a + b

# %%
print('A soma é', a + b)

# %%
print('A subtração é',  a- b)

# %%
print('A divisão é', a / b)

# %%
print('A multiplicação é', a * b)

# %%
print('O resto da divisão é', 10 % 3)

# %%
print('O resto da divisão é', 12 % 3)

# %%
print('5 elevado a 2 é', 5**2)
# Out:
# 5 elevado a 4 é 25

# %% [markdown]
# Utilizando a biblioteca math:
# <https://docs.python.org/3/library/math.html>

# %%
import math as m
m.sqrt(81)
# Out:
# 9.0

# %% [markdown]
# ## Arredondamento

# %%
casos_doenca = 134
numero_habitantes = 34432
casos_por_habitante = casos_doenca / numero_habitantes
print(casos_por_habitante)
# Out:
# 0.003891728624535316

# %%
round(casos_por_habitante, 6)
# Out:
# 0.003892

# %%
print('O número de casos por habitante é de', round(casos_por_habitante, 4))
# Out:
# O número de casos por habitante é de 0.0039

# %% [markdown]
# # Números aleatórios

# %% [markdown]
# Importe o módulo random e exiba um número aleatório entre 1 e 9:

# %%
import random

print(random.randrange(1, 10))
# Out:
# 7
